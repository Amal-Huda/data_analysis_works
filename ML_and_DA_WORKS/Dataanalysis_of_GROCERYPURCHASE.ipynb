# %%
import pandas as pd

# %%
pd.read_csv("sales.csv")
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales=pd.read_csv('sales.csv')

# %%
sales['Category']
# Out:
# 0      Groceries
# 1        Fashion
# 2       Clothing
# 3       Sporting
# 4          Books
#          ...
# 995    Groceries
# 996    Groceries
# 997     Clothing
# 998     Clothing
# 999     Clothing
# Name: Category, Length: 1000, dtype: object

# %%
sales['Category'].unique()
# Out:
# array(['Groceries', 'Fashion', 'Clothing', 'Sporting', 'Books',
#        'Furniture'], dtype=object)

# %%
sales.iloc[200]
# Out:
# Invoice ID      576523018
# Date            2/15/2018
# Time                12:35
# Gender               Male
# Location      Water tower
# City              Chicago
# Member                 No
# Category        Groceries
# Price                  82
# Quantity                1
# Total                  82
# Payment              Card
# Rating                  4
# Name: 200, dtype: object

# %%
sales.head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# 2   Clothing     57         2    114    Cash       5
# 3   Sporting     89         4    356    Gpay       1
# 4      Books     82         5    410    Cash       4

# %%
sales.tail()
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 995  Groceries     31         4    124    Card       3
# 996  Groceries      3         5     15    Gpay       3
# 997   Clothing     71         5    355    Card       3
# 998   Clothing     89         7    623    Cash       5
# 999   Clothing     31         7    217    Gpay       3

# %%
sales[200:210]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 200   576523018  2/15/2018  12:35    Male  Water tower  Chicago     No
# 201   414119922  1/30/2018  11:07    Male  Water tower  Chicago     No
# 202   123247697   2/8/2018  20:03    Male   Brookfield  NewYork     No
# 203    40419058  1/26/2018  14:53    Male  Water tower  Chicago    Yes
# 204   890497298  2/25/2018  18:06  Female  Water tower  Chicago     No
# 205   885702268  1/28/2018  12:45    Male   Brookfield  NewYork     No
# 206   172252194  3/22/2018  20:10  Female    Park lane   Dallas     No
# 207   866140211  2/25/2018  13:34  Female    Park lane   Dallas     No
# 208   597678548  3/15/2018  17:35    Male  Water tower  Chicago    Yes
# 209   428818456  2/25/2018  18:50    Male    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 200  Groceries     82         1     82    Card       4
# 201   Sporting     44         7    308    Card       3
# ...

# %%
sales[sales['Gender']=='Male']
# Out:
#      Invoice ID       Date   Time Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46   Male   Brookfield  NewYork    Yes
# 2     411909258  2/25/2018  13:33   Male  Water tower  Chicago     No
# 5     263634050   3/9/2018  17:55   Male   Brookfield  NewYork    Yes
# 6      99646662   3/4/2018  13:21   Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24   Male    Park lane   Dallas     No
# ..          ...        ...    ...    ...          ...      ...    ...
# 992   927909627   3/2/2018  13:35   Male   Brookfield  NewYork     No
# 994   446582560  1/31/2018  19:00   Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19   Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17   Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44   Male   Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales[sales['Total']>150]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5     263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6      99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 987   245049016  1/20/2018  10:03  Female    Park lane   Dallas     No
# 991   699906043  2/15/2018  12:58    Male   Brookfield  NewYork    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 1      Fashion     35         5    175    Card       3
# ...

# %%
sales[sales['Total']>150].head()
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
#
#    Category  Price  Quantity  Total Payment  Rating
# 1   Fashion     35         5    175    Card       3
# 3  Sporting     89         4    356    Gpay       1
# 4     Books     82         5    410    Cash       4
# 5  Clothing     52         4    208    Gpay       3
# 6  Clothing     81         3    243    Cash       4

# %%
sales[sales['Payment']=='Cash']
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 6      99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 989   941364541  3/13/2018  14:53  Female   Brookfield  NewYork     No
# 990   752407865  1/15/2018  10:01    Male  Water tower  Chicago    Yes
# 993   455112063  3/19/2018  17:30  Female   Brookfield  NewYork    Yes
# 994   446582560  1/31/2018  19:00    Male  Water tower  Chicago     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
#city=newyork,category unique,total
sales[sales['City']=='NewYork']
# Out:
#      Invoice ID       Date   Time  Gender    Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male  Brookfield  NewYork    Yes
# 5     263634050   3/9/2018  17:55    Male  Brookfield  NewYork    Yes
# 10    388412668  2/26/2018  11:32  Female  Brookfield  NewYork     No
# 14    547572603  3/21/2018  13:23  Female  Brookfield  NewYork     No
# 15    355981315  2/15/2018  15:47  Female  Brookfield  NewYork    Yes
# ..          ...        ...    ...     ...         ...      ...    ...
# 991   699906043  2/15/2018  12:58    Male  Brookfield  NewYork    Yes
# 992   927909627   3/2/2018  13:35    Male  Brookfield  NewYork     No
# 993   455112063  3/19/2018  17:30  Female  Brookfield  NewYork    Yes
# 997    82324424   2/6/2018  11:44    Male  Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female  Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sales['Category'].unique()
# Out:
# array(['Groceries', 'Fashion', 'Clothing', 'Sporting', 'Books',
#        'Furniture'], dtype=object)

# %%
sales100=sales[sales['Total']>100]

# %%
sales100[sales100['Total']<200]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 9     562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10    388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 977   614557665  3/22/2018  17:16  Female    Park lane   Dallas     No
# 981   418253101  3/14/2018  12:25  Female   Brookfield  NewYork     No
# 989   941364541  3/13/2018  14:53  Female   Brookfield  NewYork     No
# 994   446582560  1/31/2018  19:00    Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 1      Fashion     35         5    175    Card       3
# ...

# %%
sales['Total'].max()
# Out:
# 693

# %%
sales[sales['Total']==sales['Total'].max()]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 47    315624039  3/30/2018  19:45  Female  Water tower  Chicago    Yes
# 679   270918350  3/27/2018  13:21  Female    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 47   Groceries     99         7    693    Gpay       3
# 679  Groceries     99         7    693    Gpay       2

# %%
sales['Total'].min()
# Out:
# 1

# %%
sales[sales['Total']==sales['Total'].min()]
# Out:
#      Invoice ID       Date   Time  Gender   Location    City Member  \
# 184   801334050  1/21/2018  20:18  Female  Park lane  Dallas     No
# 587   646176653  3/10/2018  19:39    Male  Park lane  Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 184  Furniture      1         1      1    Gpay       2
# 587   Sporting      1         1      1    Cash       2

# %%
sales['Total'].mean()
# Out:
# 207.788

# %%
sales.groupby('City')

# %%
sales.groupby('City').sum()
# Out:
#            Invoice ID  Price  Quantity  Total  Rating
# City
# Chicago  164244758326  16152      1307  65215    1023
# Dallas   160721744770  17289      1344  70432    1003
# NewYork  169526550245  17671      1408  72141     946

# %%
sales.groupby('City')['Total'].sum().loc['NewYork']
# Out:
# 72141

# %%
sales.groupby('City')['Payment'].sum()
# Out:
# City
# Chicago    CardCashCashGpayCashGpayGpayCardGpayGpayCashGp...
# Dallas     GpayCashCashCardCashCardCashCashGpayCashCardCa...
# NewYork    CashGpayGpayGpayCardGpayGpayCashCardCardCardCa...
# Name: Payment, dtype: object

# %%
sales.groupby(['Gender','Payment']).sum()
# Out:
#                  Invoice ID  Price  Quantity  Total  Rating
# Gender Payment
# Female Card     81390383222   7942       604  31137     474
#        Cash     78833588163   8364       684  35298     521
#        Gpay     92914057462   9168       781  40017     522
# Male   Card     77282991281   8279       628  33127     450
#        Cash     83645175531   9199       711  37345     516
#        Gpay     80426857682   8160       651  30864     489

# %%
sales.groupby(['Gender','Payment']).sum()['Total']
# Out:
# Gender  Payment
# Female  Card       31137
#         Cash       35298
#         Gpay       40017
# Male    Card       33127
#         Cash       37345
#         Gpay       30864
# Name: Total, dtype: int64

# %%
location_list=sales.groupby('Location')

# %%
location=[x for x,y in location_list]
location
# Out:
# ['Brookfield', 'Park lane', 'Water tower']

# %%
sales.groupby('Location').sum()['Total']
# Out:
# Location
# Brookfield     72141
# Park lane      70432
# Water tower    65215
# Name: Total, dtype: int64

# %%
# highest sales is in : Brookfield
#Lowest sales is in : Water tower

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(location,sales.groupby('Location').sum()['Total'])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie(sales.groupby('Location').sum()['Total'],labels=location,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2653007b100>,
# ...
#  [Text(0.5080357843151302, 0.9756534435214743, 'Brookfield'),
#   Text(-1.0939745592878725, -0.11497679605427102, 'Park lane'),
#   Text(0.6072323961649048, -0.917207074246502, 'Water tower')],
#  [Text(0.2771104278082528, 0.5321746055571678, '34.7%'),
#   Text(-0.596713395975203, -0.06271461602960236, '33.9%'),
#   Text(0.33121767063540253, -0.5002947677708193, '31.4%')])

# %%
sales.groupby(['Location','Gender']).count()
# Out:
#                     Invoice ID  Date  Time  City  Member  Category  Price  \
# Location    Gender
# Brookfield  Female         179   179   179   179     179       179    179
#             Male           161   161   161   161     161       161    161
# Park lane   Female         179   179   179   179     179       179    179
#             Male           153   153   153   153     153       153    153
# Water tower Female         143   143   143   143     143       143    143
#             Male           185   185   185   185     185       185    185
#
#                     Quantity  Total  Payment  Rating
# Location    Gender
# Brookfield  Female       179    179      179     179
#             Male         161    161      161     161
# Park lane   Female       179    179      179     179
#             Male         153    153      153     153
# Water tower Female       143    143      143     143
#             Male         185    185      185     185

# %%
sales.groupby(['Location','Gender']).count()['Invoice ID'].unstack(level=0).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
sales.groupby(['Gender','Location']).count()['Invoice ID'].unstack(level=0).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
sales['Date']
# Out:
# 0      1/25/2018
# 1      3/19/2018
# 2      2/25/2018
# 3      1/22/2018
# 4      2/18/2018
#          ...
# 995    3/26/2018
# 996    2/20/2018
# 997     2/6/2018
# 998    1/29/2018
# 999    1/31/2018
# Name: Date, Length: 1000, dtype: object

# %%
pd.to_datetime(sales['Date'])
# Out:
# 0     2018-01-25
# 1     2018-03-19
# 2     2018-02-25
# 3     2018-01-22
# 4     2018-02-18
#          ...
# 995   2018-03-26
# 996   2018-02-20
# 997   2018-02-06
# 998   2018-01-29
# 999   2018-01-31
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
pd.to_datetime(sales['Date']).dt.day
# Out:
# 0      25
# 1      19
# 2      25
# 3      22
# 4      18
#        ..
# 995    26
# 996    20
# 997     6
# 998    29
# 999    31
# Name: Date, Length: 1000, dtype: int64

# %%
pd.to_datetime(sales['Date']).dt.month
# Out:
# 0      1
# 1      3
# 2      2
# 3      1
# 4      2
#       ..
# 995    3
# 996    2
# 997    2
# 998    1
# 999    1
# Name: Date, Length: 1000, dtype: int64

# %%
pd.to_datetime(sales['Date']).dt.year
# Out:
# 0      2018
# 1      2018
# 2      2018
# 3      2018
# 4      2018
#        ...
# 995    2018
# 996    2018
# 997    2018
# 998    2018
# 999    2018
# Name: Date, Length: 1000, dtype: int64

# %%
#create a column field to the sales report table
sales['Day']=pd.to_datetime(sales['Date']).dt.day

# %%
sales
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating  Day
# ...

# %%
sales.groupby('Day').sum()['Total']
# Out:
# Day
# 1     6301
# 2     8247
# 3     8533
# 4     6593
# 5     9177
# 6     5976
# 7     6164
# 8     8313
# 9     9142
# 10    6444
# 11    4755
# 12    7714
# 13    5688
# 14    7978
# 15    9677
# 16    5912
# 17    5833
# 18    4625
# 19    7481
# 20    7333
# 21    4300
# 22    5788
# 23    6949
# 24    7819
# 25    8638
# 26    7165
# 27    8154
# 28    6467
# 29    4662
# 30    3530
# 31    2430
# Name: Total, dtype: int64

# %%
sales.groupby('Day').sum()['Total'].plot()
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
#which branch has smallest no of members and highest number of members
#whic has highest rating and lowest
sales.groupby(['Member','Location']).count()['Invoice ID']
# Out:
# Member  Location
# No      Brookfield     173
#         Park lane      167
#         Water tower    159
# Yes     Brookfield     167
#         Park lane      165
#         Water tower    169
# Name: Invoice ID, dtype: int64

# %%
sales.groupby(['Member','Location']).count()['Invoice ID'].unstack(level=0)
# Out:
# Member        No  Yes
# Location
# Brookfield   173  167
# Park lane    167  165
# Water tower  159  169

# %%
#WAter tower has highest number of members and Park lane has the lowest

# %%
sales.groupby(['Member','Location']).count()['Invoice ID'].unstack(level=0).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
sales.groupby('Location').mean()['Rating']
# Out:
# Location
# Brookfield     2.782353
# Park lane      3.021084
# Water tower    3.118902
# Name: Rating, dtype: float64

# %%
sales.groupby('Location').mean()['Rating'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
#city has more female shopping
#spends more?
#customer spend more member or nonmember
#product sells more
#popular pdt among men and popular among women

# %%
sales.groupby(['Gender','City']).sum().unstack(level=0)['Total']
# Out:
# Gender   Female   Male
# City
# Chicago   30199  35016
# Dallas    38937  31495
# NewYork   37316  34825

# %%
sales.groupby(['Gender','City']).sum().unstack(level=0)['Total'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='City'>

# %%
#Dallas has more female shoppers
#Female spends more

# %%
sales.groupby('Member').sum()['Total']
# Out:
# Member
# No     100245
# Yes    107543
# Name: Total, dtype: int64

# %%
sales.groupby('Member').sum()['Total'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Member'>

# %%
#member customers spend more

# %%
sales.groupby('Category').sum()
# Out:
#             Invoice ID  Price  Quantity  Total  Rating   Day
# Category
# Books      88893818546   8599       681  36103     481  2426
# Clothing   81108451727   8683       705  35925     509  2522
# Fashion    71772534650   8055       628  32778     458  2477
# Furniture  71185482977   8188       668  34141     506  2215
# Groceries  88063827178   8372       660  31236     512  2785
# Sporting   93468938263   9215       717  37605     506  2831

# %%
sales.groupby('Category').sum()['Quantity']
# Out:
# Category
# Books        681
# Clothing     705
# Fashion      628
# Furniture    668
# Groceries    660
# Sporting     717
# Name: Quantity, dtype: int64

# %%
sales.groupby('Category').sum()['Quantity'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
#sporting is the product category which sell more

# %%
sales.groupby(['Category','Gender']).sum()
# Out:
#                    Invoice ID  Price  Quantity  Total  Rating   Day
# Category  Gender
# Books     Female  49739580306   4480       370  18793     267  1280
#           Male    39154238240   4119       311  17310     214  1146
# Clothing  Female  39105066388   4047       353  17883     256  1321
#           Male    42003385339   4636       352  18042     253  1201
# Fashion   Female  37034076979   4130       346  17784     234  1286
#           Male    34738457671   3925       282  14994     224  1191
# Furniture Female  36557881972   3557       330  15307     256  1105
#           Male    34627601005   4631       338  18834     250  1110
# Groceries Female  44935654674   4493       334  17300     266  1393
#           Male    43128172504   3879       326  13936     246  1392
# Sporting  Female  45765768528   4767       336  19385     238  1315
#           Male    47703169735   4448       381  18220     268  1516

# %%
sales.groupby(['Category','Gender']).sum()['Quantity']
# Out:
# Category   Gender
# Books      Female    370
#            Male      311
# Clothing   Female    353
#            Male      352
# Fashion    Female    346
#            Male      282
# Furniture  Female    330
#            Male      338
# Groceries  Female    334
#            Male      326
# Sporting   Female    336
#            Male      381
# Name: Quantity, dtype: int64

# %%
sales.groupby(['Category','Gender']).sum()['Quantity'].unstack(level=0)
# Out:
# Category  Books  Clothing  Fashion  Furniture  Groceries  Sporting
# Gender
# Female      370       353      346        330        334       336
# Male        311       352      282        338        326       381

# %%
sales.groupby(['Category','Gender']).sum()['Quantity'].unstack(level=0).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
#popular product among male is sporting
#popular product among female is books

# %%
#month having more sales

# %%
sales['Month']=pd.to_datetime(sales['Date']).dt.month

# %%
sales['Month']
# Out:
# 0      1
# 1      3
# 2      2
# 3      1
# 4      2
#       ..
# 995    3
# 996    2
# 997    2
# 998    1
# 999    1
# Name: Month, Length: 1000, dtype: int64

# %%
sales['Month'].dt.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5372/2770409980.py in <module>
# ----> 1 sales['Month'].dt.month
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
sales
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating  Day  Month
# ...

# %%
sales.groupby('Month').sum()['Total']
# Out:
# Month
# 1    71652
# 2    63850
# 3    72286
# Name: Total, dtype: int64

# %%
sales.groupby('Month').sum()['Total'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
#Month 3 has the highest sale
